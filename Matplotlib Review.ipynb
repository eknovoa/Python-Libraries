# %% [markdown]
# # Matplotlib Review #

# %% [markdown]
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0,5])
ypoints = np.array([0,250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# The plot() function is used to draw points (markers) in a diagram.
#
# By default: draws a line from point to point.
#
# The function takes parameters for specifying points in diagram
# Param 1: array containing points on x-axis
# Param 2: array containing points on y-axis
#
# x-axis: horizontal axis
# y-axis: vertical axis

# %%
xpoints2 = np.array([5,10])
ypoints2 = np.array([10,10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# the third argument was a marker which can be used used to specify each point with a marker (you can use the marker keyword as well)
#
# you can plot as many points as you like, but make sure you have same number of points in both axis
#
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.
#
# You can also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color
#
# # line
# '-' solid line
# ':' dotted line
# '--' dashed line
# '-.' dashed/dotted line
#
# # color
# 'r' - red
# 'g' - green
# 'b' - blue
# 'c' - cyan
# 'm' - magenta
# 'y' - yellow
# 'k' - black
# 'w' - white
#
#
# Then let's set the size of the markers using the markersize keyword argument or the shorter version, ms.
#
# Use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers.
#
# Use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers.
#
# You can also use the keyword argument linestyle, or shorter ls, to change the style of the plotted line.
#
# You can use the keyword argument color or the shorter c to set the color of the line.
#
# You can use the keyword argument linewidth or the shorter lw to change the width of the line.

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([0,1,2,3])

plt.title('sample chart')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.plot(x,y)
plt.show()

# %% [markdown]
# set front properties in the title and labels with fontdict paramter

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# position the title with the loc parameter
#
# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1, loc="left")
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# what if we want to add grid lines to the plot?

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# You can use the axis parameter in the grid() function to specify which grid lines to display.
#
# Legal values are: 'x', 'y', and 'both'. Default value is 'both'.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %% [markdown]
# You can also set the line properties of the grid, like this: grid(color = 'color', linestyle = 'linestyle', linewidth = number).
#
#
# With the subplot() function you can draw multiple plots in one figure:

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# The subplot() function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.
#
# The third argument represents the index of the current plot.
#
#
#
# You can add a title to the entire figure with the suptitle() function:

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# ### creatings scatter plots
#
# scatter() function plots oe dot for each observation and this function needs two arrays of the same length as arguments, one with values for x-axis and the second for values on the y-axis
#
# scatter plots are used to observe and identify any relationships between two variables

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y)
plt.xlabel('age of car')
plt.ylabel('speed of car')
plt.show()

# %% [markdown]
# use the color argument or c argument to set a specific color for each dot observation
#
# you can use the c argument if you want to pass in an array of colors to assign a specific color to each dot

# %% [markdown]
# Matplotlib module also has colormaps.
#
# A colormap is a list of colors, where each color has a value that ranges from 0 to 100.
#
# Here is an example of creating a color array and specifying a colormap in the scatter plot.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

# to include the colormap in drawing use this statement
plt.colorbar()

plt.show()

# %% [markdown]
# Now set different sizes for each markers but make sure the array of sizes is equivalent to the length of arrays for the x-axis and y-axis.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# Now let's adjust the transparency of the dats with the alpha argument. Make sure the array of sizes has the same length as the arrays for the x-axis and y-axis.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %% [markdown]
# You can combine a colormap with different sizes of the dots but this is best visualized if the dots are transparent.

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# ### Let's move on to Bar Graphs

# %%
x = np.array(['A', 'B', 'C', 'D'])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# What if we want to display the bars horizontally?
#
# Use the barh() function.

# %%
x = np.array(['A', 'B', 'C', 'D'])
y = np.array([3, 8, 1, 10])

plt.barh(x,y)
plt.show()

# %% [markdown]
# Takes the following arguments:
# - color
# - width (default width is 0.8)
# - height (for horizontal bars instead of width - default is 0.8)

# %% [markdown]
# ### Histograms
#
# a histogram is a graph that shows frequency distributions
#
# it show the number of observations within each given interval

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# ### Pie Charts

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
#
# The startangle parameter is defined with an angle in degrees, default angle is 0:

# %% [markdown]
# ![Screenshot%202024-04-08%20at%203.25.17%E2%80%AFPM.png](attachment:Screenshot%202024-04-08%20at%203.25.17%E2%80%AFPM.png)

# %% [markdown]
# Maybe you want one of the wedges to stand out? The explode parameter allows you to do that.
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed:

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# Add a shadow to the pie chart by setting the shadows parameter to True:

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# To add a list of explanation for each wedge, use the legend() function:

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# To add a header to the legend, add the title parameter to the legend function.

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %% [markdown]
# Source: W3Schools
